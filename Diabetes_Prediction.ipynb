# %%
# !pip install numpy
# !pip install pandas
# !pip insstall scikit-learn
# !pip install random
# !pip install matplotlib
# Out:
# ...
# ERROR: unknown command "insstall" - maybe you meant "install"
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.metrics import accuracy_score, f1_score, recall_score, precision_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('/content/diabetes_prediction_dataset.csv')
dataset
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
dataset.head().sum()
# Out:
# gender                      FemaleFemaleMaleFemaleMale
# age                                              274.0
# hypertension                                         1
# heart_disease                                        2
# smoking_history        neverNo Infonevercurrentcurrent
# bmi                                             123.42
# HbA1c_level                                       28.7
# blood_glucose_level                                688
# diabetes                                             0
# dtype: object

# %%
dataset.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %%
dataset['diabetes'].unique()
# Out:
# array([0, 1])

# %%
dataset.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
dataset['blood_glucose_level'].unique()
# Out:
# array([140,  80, 158, 155,  85, 200, 145, 100, 130, 160, 126, 159,  90,
#        260, 220, 300, 280, 240])

# %%
dataset['bmi'] = dataset['bmi'].astype(int)

# %%
dataset['blood_glucose_level']
# Out:
# 0        140
# 1         80
# 2        158
# 3        155
# 4        155
#         ...
# 99995     90
# 99996    100
# 99997    155
# 99998    100
# 99999     90
# Name: blood_glucose_level, Length: 100000, dtype: int64

# %%
datasetA = dataset[['blood_glucose_level','bmi']]

# %%
datasetB['smoking_history'].unique()
datasetB['smoking_history'] = datasetB['smoking_history'].map({'never': 0, 'current': 1, 'former': 1, 'ever':1, 'not current': 1, 'No Info': 0})

# %%
# Out:
#        gender   age  hypertension  heart_disease smoking_history  HbA1c_level  \
# 0           0  80.0             0              1           never          6.6
# 1           0  54.0             0              0         No Info          6.6
# 2           1  28.0             0              0           never          5.7
# 3           0  36.0             0              0         current          5.0
# 4           1  76.0             1              1         current          4.8
# ...       ...   ...           ...            ...             ...          ...
# 99995       0  80.0             0              0         No Info          6.2
# 99996       0   2.0             0              0         No Info          6.5
# 99997       1  66.0             0              0          former          5.7
# 99998       0  24.0             0              0           never          4.0
# 99999       0  57.0             0              0         current          6.6
#
#        diabetes
# ...

# %%
datasetA.sum()
# Out:
# blood_glucose_level    13805806
# bmi                     2687458
# dtype: int64

# %%
x = datasetA
y = datasetB

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = StandardScaler()
X_train = model.fit_transform(X_train)
X_test = model.transform(X_test)

y_train_reshaped = y_train.values.reshape(-1, 1)
y_test_reshape = y_test.values.reshape(-1, 1)

# %% [markdown]
# Linear Regression

# %%
Linear = LinearRegression()
Linear.fit(X_train, y_train_reshaped)
y_pred = Linear.predict(X_test)
y_p = (y_pred > 0.5)
print('Linear Regression')
print('Accuracy: ', accuracy_score(y_test_reshape, y_p))
print('f1_score:', f1_score(y_test_reshape, y_p))
print('recall_score:', recall_score(y_test_reshape, y_p))
print('precision_score:', precision_score(y_test_reshape, y_p))
# Out:
# Linear Regression
# Accuracy:  0.9257
# f1_score: 0.23559670781893005
# recall_score: 0.13407494145199064
# precision_score: 0.9703389830508474

# %% [markdown]
# Logistic Regression

# %%
Logistic = LogisticRegression()
Logistic.fit(X_train, y_train)
y_pred = Logistic.predict(X_test)
print('Logistic Regression')
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('f1-score: ', f1_score(y_test, y_pred))
print('recall_score:', recall_score(y_test, y_pred))
print('precision_score:', precision_score(y_test, y_pred))
# Out:
# Logistic Regression
# Accuracy:  0.9397
# f1-score:  0.49708090075062555
# recall_score: 0.34894613583138173
# precision_score: 0.863768115942029

# %% [markdown]
# Decision Tree Classifier

# %%
DT = DecisionTreeClassifier()
DT.fit(X_train, y_train)
y_pred = DT.predict(X_test)
print('Decision Tree')
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('f1-score: ', f1_score(y_test, y_pred))
print('recall_score:', recall_score(y_test, y_pred))
print('precision_score:', precision_score(y_test, y_pred))
# Out:
# Decision Tree
# Accuracy:  0.94665
# f1-score:  0.5518689626207476
# recall_score: 0.38466042154566743
# precision_score: 0.9762258543833581

# %% [markdown]
# Random Tree Classifier

# %%
RT = RandomForestClassifier()
RT.fit(X_train, y_train)
y_pred = RT.predict(X_test)
print('Random Forest')
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('f1-score: ', f1_score(y_test, y_pred))
print('recall_score:', recall_score(y_test, y_pred))
print('precision_score:', precision_score(y_test, y_pred))
# Out:
# Random Forest
# Accuracy:  0.9465
# f1-score:  0.5519262981574539
# recall_score: 0.38583138173302106
# precision_score: 0.9691176470588235

# %% [markdown]
# AdaBoost Classifier

# %%
AD = AdaBoostClassifier()
AD.fit(X_train, y_train)
y_pred = AD.predict(X_test)
print('AdaBoostClassifier')
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('f1-score: ', f1_score(y_test, y_pred))
print('recall_score:', recall_score(y_test, y_pred))
print('precision_score:', precision_score(y_test, y_pred))
# Out:
# AdaBoostClassifier
# Accuracy:  0.94725
# f1-score:  0.5531554426090639
# recall_score: 0.38231850117096017
# precision_score: 1.0

# %% [markdown]
# K Nearest Neighbors

# %%
KNN = KNeighborsClassifier()
KNN.fit(X_train, y_train)
y_pred = KNN.predict(X_test)
print('K Nearest Neighbours')
print('Accuracy: ', accuracy_score(y_test, y_pred))
print('f1-score: ', f1_score(y_test, y_pred))
print('recall_score:', recall_score(y_test, y_pred))
print('precision_score:', precision_score(y_test, y_pred))
# Out:
# K Nearest Neighbours
# Accuracy:  0.94325
# f1-score:  0.5543776992540244
# recall_score: 0.4133489461358314
# precision_score: 0.8414779499404053
